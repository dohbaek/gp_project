# %%
# !conda install --yes -c menpo scipy imageio opencv3
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.5.4
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.

# %%
# %load main.py
import argparse, os
from GAN import GAN
from CGAN import CGAN
from LSGAN import LSGAN
from DRAGAN import DRAGAN
from ACGAN import ACGAN
from WGAN import WGAN
from WGAN_GP import WGAN_GP
from infoGAN import infoGAN
from EBGAN import EBGAN
from BEGAN import BEGAN

import numpy as np
import cv2
import torch
import utils
from torch.autograd import Variable

# %%
class ARGS(object):
    def __init__(self, name, epoch):
        self.epoch = epoch
        self.batch_size = 64
        self.dataset = 'celebA'
        self.gpu_mode = True
        self.lrG = 0.0002
        self.lrD = 0.0002
        self.beta1 = 0.5
        self.beta2 = 0.999
        
        self.gan_type = name
        self.save_dir = name + '/save'
        self.result_dir = name + '/result'
        self.log_dir = name + '/log'

# %%
def generateDataset(gan, number):
    if not os.path.exists(gan.model_name + '/dataset'):
            os.makedirs(gan.model_name + '/dataset')
    for x in range (0, number):
        sample_z_ = Variable(torch.rand((gan.batch_size, gan.z_dim)).cuda(), volatile=True)
        samples = gan.G(sample_z_)
        samples = samples.cpu().data.numpy().transpose(0, 2, 3, 1)
        utils.save_images(samples[:1, :, :, :], [1, 1], gan.model_name + '/dataset/' + str(x) + '.png')
        img = cv2.imread(gan.model_name + '/dataset/' + str(x) + '.png')
        res = cv2.resize(img, dsize = (128, 128))
        cv2.imwrite(gan.model_name + '/dataset/' + str(x) + '.png', res)

# %%
gan = GAN(ARGS('GAN', 1))
gan.train()
generateDataset(gan, 200)

wgan = WGAN(ARGS('WGAN', 1))
wgan.train()
generateDataset(wgan, 200)

began = BEGAN(ARGS('BEGAN', 1))
began.train()
generateDataset(began, 200)
# Out:
# ---------- Networks architecture -------------
# generator(
#   (fc): Sequential(
#     (0): Linear(in_features=62, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=1024, out_features=32768, bias=True)
#     (4): BatchNorm1d(32768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (deconv): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): Sigmoid()
#   )
# )
# Total number of parameters: 33853635
# discriminator(
#   (conv): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=32768, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Linear(in_features=1024, out_features=1, bias=True)
#     (4): Sigmoid()
#   )
# )
# Total number of parameters: 33693121
# -----------------------------------------------
# /home/ubuntu/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/torchvision-0.2.1-py2.7.egg/torchvision/transforms/transforms.py:188: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
# GAN.py:138: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.sample_z_ = Variable(torch.rand((self.batch_size, self.z_dim)).cuda(), volatile=True)
# GAN.py:188: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   self.train_hist['D_loss'].append(D_loss.data[0])
# GAN.py:189: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   self.rfloss_hist['Real_loss'].append(D_real_loss.data[0])
# GAN.py:190: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   self.rfloss_hist['Fake_loss'].append(D_fake_loss.data[0])
# training start!!
# GAN.py:201: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   self.train_hist['G_loss'].append(G_loss.data[0])
# GAN.py:208: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#
# Epoch: [25] [ 400/1258] D_loss: 0.51124460, G_loss: 2.59037781
# Epoch: [25] [ 500/1258] D_loss: 0.60745013, G_loss: 2.83425331
# Epoch: [25] [ 600/1258] D_loss: 0.42544004, G_loss: 2.24266434
# Epoch: [25] [ 700/1258] D_loss: 0.57957900, G_loss: 2.94257641
# Epoch: [25] [ 800/1258] D_loss: 0.57554734, G_loss: 2.01173115
# Epoch: [25] [ 900/1258] D_loss: 0.43536055, G_loss: 2.26421547
# Epoch: [25] [1000/1258] D_loss: 0.57272041, G_loss: 2.00442863
# Epoch: [25] [1100/1258] D_loss: 0.79788613, G_loss: 2.79857469
# Epoch: [25] [1200/1258] D_loss: 0.44338998, G_loss: 2.50100064
# Avg one epoch time: 216.90, total 25 epochs time: 5423.18
# Training finish!... save training results
# ---------------------------------------------------------------
# OSError                       Traceback (most recent call last)
# <ipython-input-4-db36ae44acd4> in <module>()
#       1 gan = GAN(ARGS('GAN', 25))
# ----> 2 gan.train()
#       3 generateDataset(gan, 20000)
#       4
#       5 wgan = WGAN(ARGS('WGAN', 25))
#
# /home/ubuntu/male/gp_project/GAN.py in train(self)
#     222         self.save()
#     223         utils.generate_animation(self.result_dir + '/' + self.dataset + '/' + self.model_name + '/' + self.model_name,
# --> 224                                  self.epoch)
#     225         utils.loss_plot(self.train_hist, os.path.join(self.save_dir), self.model_name)
#     226         utils.rfloss_plot(self.rfloss_hist, os.path.join(self.save_dir), self.model_name)
#
# /home/ubuntu/male/gp_project/utils.pyc in generate_animation(path, num)
#     105     for e in range(num):
#     106         img_name = path + '_epoch%03d' % (e+1) + '.png'
# --> 107         images.append(imageio.imread(img_name))
#     108     imageio.mimsave(path + '_generate_animation.gif', images, fps=5)
#     109
#
# /home/ubuntu/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/imageio/core/functions.pyc in imread(uri, format, **kwargs)
#     204
#     205     # Get reader and read first
# --> 206     reader = read(uri, format, 'i', **kwargs)
#     207     with reader:
#     208         return reader.get_data(0)
#
# /home/ubuntu/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/imageio/core/functions.pyc in get_reader(uri, format, mode, **kwargs)
#     115
#     116     # Create request object
# --> 117     request = Request(uri, 'r' + mode, **kwargs)
#     118
#     119     # Get format
#
# /home/ubuntu/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/imageio/core/request.pyc in __init__(self, uri, mode, **kwargs)
#     126
#     127         # Parse what was given
# --> 128         self._parse_uri(uri)
#     129
#     130         # Set extension
#
# /home/ubuntu/anaconda3/envs/pytorch_p27/lib/python2.7/site-packages/imageio/core/request.pyc in _parse_uri(self, uri)
#     269                 # Reading: check that the file exists (but is allowed a dir)
#     270                 if not os.path.exists(fn):
# --> 271                     raise FileNotFoundError("No such file: '%s'" % fn)
#     272             else:
#     273                 # Writing: check that the directory to write to does exist
#
# OSError: No such file: '/home/ubuntu/male/gp_project/GAN/result/celebA/GAN/GAN_epoch001.png'
